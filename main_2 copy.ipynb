# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from ast import literal_eval

# %% [markdown]
# ### Load & Preprocess data

# %%
tmdb_5000_credits = pd.read_csv("datasets/movies-2/tmdb_5000_credits.csv")
tmdb_5000_movies = pd.read_csv("datasets/movies-2/tmdb_5000_movies.csv")

# %%
columns_movies = ["budget", "genres", "id", "original_language", "original_title", "overview", "popularity", "production_countries", "release_date", "spoken_languages", "vote_average", "vote_count"]
columns_credits = ["movie_id", "title", "cast", "crew"]

tmdb_5000_movies = tmdb_5000_movies[columns_movies]
tmdb_5000_credits = tmdb_5000_credits[columns_credits]

for column in ["genres", "production_countries", "spoken_languages"]:
    tmdb_5000_movies[column] = tmdb_5000_movies[column].apply(literal_eval)

for column in ["crew", "cast"]:
    tmdb_5000_credits[column] = tmdb_5000_credits[column].apply(literal_eval)

# %%
tmdb_5000_credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...

# %%
tmdb_5000_movies.head(5)
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   19995
# 1  300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...     285
# 2  245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  206647
# 3  250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   49026
# 4  260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-10
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2007-05-19
# 2  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2015-10-26
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-07-16
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-03-07
#
#                                     spoken_languages  vote_average  vote_count
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...           7.2       11800
# 1           [{'iso_639_1': 'en', 'name': 'English'}]           6.9        4500
# 2  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...           6.3        4466
# 3           [{'iso_639_1': 'en', 'name': 'English'}]           7.6        9106
# 4           [{'iso_639_1': 'en', 'name': 'English'}]           6.1        2124

# %%
def preprocess_dict(column: str, key: str = "name"):
    genres_column = tmdb_5000_movies[column]
    genres_column_processed = []
    for item in genres_column:
        genres_column_processed.append([dic[key] for dic in item])
    return genres_column_processed

# %%
tmdb_5000_movies["genres"] = preprocess_dict("genres")
tmdb_5000_movies["production_countries"] = preprocess_dict("production_countries")
tmdb_5000_movies["spoken_languages"] = preprocess_dict("spoken_languages")

# %%
tmdb_5000_movies.head(5)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                          production_countries release_date  \
# 0  [United States of America, United Kingdom]   2009-12-10
# 1                  [United States of America]   2007-05-19
# 2  [United Kingdom, United States of America]   2015-10-26
# 3                  [United States of America]   2012-07-16
# 4                  [United States of America]   2012-03-07
#
#                                   spoken_languages  vote_average  vote_count
# 0                               [English, Español]           7.2       11800
# 1                                        [English]           6.9        4500
# 2  [Français, English, Español, Italiano, Deutsch]           6.3        4466
# 3                                        [English]           7.6        9106
# 4                                        [English]           6.1        2124

# %%
tmdb_5000_movies = tmdb_5000_movies.merge(tmdb_5000_credits, left_on='id', right_on='movie_id')

# %%
print(tmdb_5000_movies.shape)
tmdb_5000_movies = tmdb_5000_movies.query("budget != 0")
print(tmdb_5000_movies.shape)
# Out:
# (4803, 16)
# (3766, 16)

# %%
tmdb_5000_movies["cast"] = preprocess_dict("cast", "character")

# %%
tmdb_5000_movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                          production_countries release_date  \
# 0  [United States of America, United Kingdom]   2009-12-10
# 1                  [United States of America]   2007-05-19
# 2  [United Kingdom, United States of America]   2015-10-26
# 3                  [United States of America]   2012-07-16
# 4                  [United States of America]   2012-03-07
#
#                                   spoken_languages  vote_average  vote_count  \
# 0                               [English, Español]           7.2       11800
# 1                                        [English]           6.9        4500
# 2  [Français, English, Español, Italiano, Deutsch]           6.3        4466
# 3                                        [English]           7.6        9106
# 4                                        [English]           6.1        2124
#
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [Jake Sully, Neytiri, Dr. Grace Augustine, Col...
# 1  [Captain Jack Sparrow, Will Turner, Elizabeth ...
# 2  [James Bond, Blofeld, Madeleine, M, Lucia, Q, ...
# 3  [Bruce Wayne / Batman, Alfred Pennyworth, Jame...
# 4  [John Carter, Dejah Thoris, Sola, Tars Tarkas,...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...

# %%
tmdb_5000_movies['overview'].head()
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %% [markdown]
# ### Con la overview

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
tmdb_5000_movies['overview'] = tmdb_5000_movies['overview'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(tmdb_5000_movies['overview'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (3766, 18162)

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(tmdb_5000_movies.index, index=tmdb_5000_movies['original_title']).drop_duplicates()

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return tmdb_5000_movies[['original_title', 'production_countries', 'genres', 'vote_average']].iloc[movie_indices]

# %%
get_recommendations('The Dark Knight Rises')
# Out:
#                                original_title  \
# 65                            The Dark Knight
# 298                            Batman Forever
# 423                            Batman Returns
# 1305                                   Batman
# 3279  Batman: The Dark Knight Returns, Part 2
# 2293                                Slow Burn
# 119                             Batman Begins
# 1145                                      JFK
# 9          Batman v Superman: Dawn of Justice
# 210                            Batman & Robin
#
#                             production_countries  \
# 65    [United Kingdom, United States of America]
# 298   [United Kingdom, United States of America]
# 423   [United Kingdom, United States of America]
# 1305  [United Kingdom, United States of America]
# 3279                  [United States of America]
# 2293                  [United States of America]
# 119   [United Kingdom, United States of America]
# 1145                  [United States of America]
# 9                     [United States of America]
# 210   [United Kingdom, United States of America]
#
#                                  genres  vote_average
# 65     [drama, action, crime, thriller]           8.2
# 298            [action, crime, fantasy]           5.2
# 423                   [action, fantasy]           6.6
# 1305                  [fantasy, action]           7.0
# 3279                [action, animation]           7.9
# 2293  [mystery, crime, drama, thriller]           5.5
# 119              [action, crime, drama]           7.5
# 1145         [drama, thriller, history]           7.5
# 9          [action, adventure, fantasy]           5.7
# 210            [action, crime, fantasy]           4.2

# %% [markdown]
# ### Por categoria de peli

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
def get_list(x):
    if isinstance(x, list):
        #Check if more than 3 elements exist. If yes, return only first three. If no, return entire list.
        if len(x) > 5:
            x = x[:5]
        return x

    #Return empty list in case of missing/malformed data
    return []

# %%
tmdb_5000_movies['director'] = tmdb_5000_movies['crew'].apply(get_director)

features = ['cast', 'genres']
for feature in features:
    tmdb_5000_movies[feature] = tmdb_5000_movies[feature].apply(get_list)

# %%
tmdb_5000_movies[['original_title', 'cast', 'director', 'genres']].head(3)
# Out:
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast        director  \
# 0  [Jake Sully, Neytiri, Dr. Grace Augustine, Col...   James Cameron
# 1  [Captain Jack Sparrow, Will Turner, Elizabeth ...  Gore Verbinski
# 2         [James Bond, Blofeld, Madeleine, M, Lucia]      Sam Mendes
#
#                                           genres
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['cast', 'director', 'genres']

for feature in features:
    tmdb_5000_movies[feature] = tmdb_5000_movies[feature].apply(clean_data)

# %%
tmdb_5000_movies.head()
# Out:
#       budget                                        genres      id  \
# 0  237000000  [action, adventure, fantasy, sciencefiction]   19995
# 1  300000000                  [adventure, fantasy, action]     285
# 2  245000000                    [action, adventure, crime]  206647
# 3  250000000              [action, crime, drama, thriller]   49026
# 4  260000000           [action, adventure, sciencefiction]   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                          production_countries release_date  \
# 0  [United States of America, United Kingdom]   2009-12-10
# 1                  [United States of America]   2007-05-19
# 2  [United Kingdom, United States of America]   2015-10-26
# 3                  [United States of America]   2012-07-16
# 4                  [United States of America]   2012-03-07
#
#                                   spoken_languages  vote_average  vote_count  \
# 0                               [English, Español]           7.2       11800
# 1                                        [English]           6.9        4500
# 2  [Français, English, Español, Italiano, Deutsch]           6.3        4466
# 3                                        [English]           7.6        9106
# 4                                        [English]           6.1        2124
#
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [jakesully, neytiri, dr.graceaugustine, col.qu...
# 1  [captainjacksparrow, willturner, elizabethswan...
# 2          [jamesbond, blofeld, madeleine, m, lucia]
# 3  [brucewayne/batman, alfredpennyworth, jamesgor...
# 4  [johncarter, dejahthoris, sola, tarstarkas, ta...
#
#                                                 crew          director
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...      jamescameron
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...     goreverbinski
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...         sammendes
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...  christophernolan
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...     andrewstanton

# %%
def create_soup(x):
    return ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])
tmdb_5000_movies['soup'] = tmdb_5000_movies.apply(create_soup, axis=1)

# %%
tmdb_5000_movies['soup'].head()
# Out:
# 0    jakesully neytiri dr.graceaugustine col.quarit...
# 1    captainjacksparrow willturner elizabethswann w...
# 2    jamesbond blofeld madeleine m lucia sammendes ...
# 3    brucewayne/batman alfredpennyworth jamesgordon...
# 4    johncarter dejahthoris sola tarstarkas talhaju...
# Name: soup, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(tmdb_5000_movies['soup'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
tmdb_5000_movies = tmdb_5000_movies.reset_index()
indices = pd.Series(tmdb_5000_movies.index, index=tmdb_5000_movies['original_title'])

# %%
tmdb_5000_movies.query("original_title == 'The Dark Knight Rises'")["genres"]
# Out:
# 3    [action, crime, drama, thriller]
# Name: genres, dtype: object

# %%
get_recommendations('The Dark Knight Rises', cosine_sim2)
# Out:
#                              original_title  \
# 119                           Batman Begins
# 65                          The Dark Knight
# 3705               Amidst the Devil's Wings
# 423                          Batman Returns
# 402   The Fast and the Furious: Tokyo Drift
# 1439                                 Takers
# 3051                              ต้มยำกุ้ง
# 616                          Need for Speed
# 743                          Righteous Kill
# 825                              The Hunted
#
#                                    production_countries  \
# 119          [United Kingdom, United States of America]
# 65           [United Kingdom, United States of America]
# 3705                         [United States of America]
# 423          [United Kingdom, United States of America]
# 402                   [Japan, United States of America]
# 1439                         [United States of America]
# 3051                              [Thailand, Australia]
# 616   [Philippines, United States of America, United...
# 743                          [United States of America]
# 825                          [United States of America]
#
#                                 genres  vote_average
# 119             [action, crime, drama]           7.5
# 65    [drama, action, crime, thriller]           8.2
# 3705            [drama, action, crime]           0.0
# 423                  [action, fantasy]           6.6
# 402   [action, crime, drama, thriller]           6.1
# 1439  [action, crime, drama, thriller]           6.0
# 3051  [action, crime, drama, thriller]           6.8
# 616   [action, crime, drama, thriller]           6.1
# 743   [action, crime, drama, thriller]           5.9
# 825   [drama, action, thriller, crime]           6.0
