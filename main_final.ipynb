# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ### Load & Preprocess data

# %%
tmdb_5000_credits = pd.read_csv("datasets/movies-2/tmdb_5000_credits.csv")
tmdb_5000_movies = pd.read_csv("datasets/movies-2/tmdb_5000_movies.csv")

# %%
columns_movies = ["budget", "genres", "id", "original_language", "original_title", "overview", "popularity", "production_countries", "release_date", "spoken_languages", "vote_average", "vote_count"]
columns_credits = ["movie_id", "title", "cast", "crew"]

tmdb_5000_movies = tmdb_5000_movies[columns_movies]
tmdb_5000_credits = tmdb_5000_credits[columns_credits]

for column in ["genres", "production_countries", "spoken_languages"]:
    tmdb_5000_movies[column] = tmdb_5000_movies[column].apply(literal_eval)

for column in ["crew", "cast"]:
    tmdb_5000_credits[column] = tmdb_5000_credits[column].apply(literal_eval)

# %%
tmdb_5000_credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...

# %%
tmdb_5000_movies.head(5)
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   19995
# 1  300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...     285
# 2  245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  206647
# 3  250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   49026
# 4  260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-10
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2007-05-19
# 2  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2015-10-26
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-07-16
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-03-07
#
#                                     spoken_languages  vote_average  vote_count
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...           7.2       11800
# 1           [{'iso_639_1': 'en', 'name': 'English'}]           6.9        4500
# 2  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...           6.3        4466
# 3           [{'iso_639_1': 'en', 'name': 'English'}]           7.6        9106
# 4           [{'iso_639_1': 'en', 'name': 'English'}]           6.1        2124

# %%
def preprocess_dict(column: str, key: str = "name"):
    genres_column = tmdb_5000_movies[column]
    genres_column_processed = []
    for item in genres_column:
        genres_column_processed.append([dic[key] for dic in item])
    return genres_column_processed

# %%
tmdb_5000_movies["genres"] = preprocess_dict("genres")
tmdb_5000_movies["production_countries"] = preprocess_dict("production_countries")
tmdb_5000_movies["spoken_languages"] = preprocess_dict("spoken_languages")

# %%
tmdb_5000_movies.head(5)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                          production_countries release_date  \
# 0  [United States of America, United Kingdom]   2009-12-10
# 1                  [United States of America]   2007-05-19
# 2  [United Kingdom, United States of America]   2015-10-26
# 3                  [United States of America]   2012-07-16
# 4                  [United States of America]   2012-03-07
#
#                                   spoken_languages  vote_average  vote_count
# 0                               [English, Español]           7.2       11800
# 1                                        [English]           6.9        4500
# 2  [Français, English, Español, Italiano, Deutsch]           6.3        4466
# 3                                        [English]           7.6        9106
# 4                                        [English]           6.1        2124

# %%
tmdb_5000_movies = tmdb_5000_movies.merge(tmdb_5000_credits, left_on='id', right_on='movie_id')

# %%
print(tmdb_5000_movies.shape)
tmdb_5000_movies = tmdb_5000_movies[tmdb_5000_movies['budget'].apply(lambda x: x > 0)]
tmdb_5000_movies = tmdb_5000_movies[tmdb_5000_movies['genres'].apply(lambda x: len(x) > 0)]
print(tmdb_5000_movies.shape)
# Out:
# (4803, 16)
# (3762, 16)

# %%
tmdb_5000_movies = tmdb_5000_movies.reset_index(drop=True)

# %%
tmdb_5000_movies["cast"] = preprocess_dict("cast", "name")

# %%
tmdb_5000_movies.tail()
# Out:
#       budget                              genres      id original_language  \
# 3757      13                            [horror]  157185                en
# 3758   20000  [crime, horror, mystery, thriller]   36095                ja
# 3759    7000   [sciencefiction, drama, thriller]   14337                en
# 3760  220000           [action, crime, thriller]    9367                es
# 3761    9000                   [comedy, romance]   72766                en
#
#      original_title                                           overview  \
# 3757    Tin Can Man  Recently dumped by his girlfirend for another ...
# 3758            キュア  A wave of gruesome murders is sweeping Tokyo. ...
# 3759         Primer  Friends/fledgling entrepreneurs invent a devic...
# 3760    El Mariachi  El Mariachi just wants to play his guitar and ...
# 3761      Newlyweds  A newlywed couple's honeymoon is upended by th...
#
#       popularity                production_countries release_date  \
# 3757    0.332679                           [Ireland]   2007-01-01
# 3758    0.212443                             [Japan]   1997-11-06
# 3759   23.307949          [United States of America]   2004-10-08
# 3760   14.269792  [Mexico, United States of America]   1992-09-04
# 3761    0.642552                                  []   2011-12-26
#
#      spoken_languages  vote_average  vote_count  movie_id        title  \
# 3757        [English]           2.0           1    157185  Tin Can Man
# 3758            [日本語]           7.4          63     36095         Cure
# 3759        [English]           6.9         658     14337       Primer
# 3760        [Español]           6.6         238      9367  El Mariachi
# 3761               []           5.9           5     72766    Newlyweds
#
#                                                    cast  \
# 3757  [michaelparle, emmaelizaregan, patricko'donnel...
# 3758  [kojiyakusho, masatohagiwara, tsuyoshiujiki, a...
# 3759  [shanecarruth, davidsullivan, caseygooden, ana...
# 3760  [carlosgallardo, jaimedehoyos, petermarquardt,...
# 3761  [edwardburns, kerrybishé, marshadietlein, cait...
#
#                                                    crew         director  \
# 3757  [{'credit_id': '54c7851b925141679100372a', 'de...     ivankavanagh
# 3758  [{'credit_id': '52fe45cc9251416c9103eb7b', 'de...  kiyoshikurosawa
# 3759  [{'credit_id': '52fe45e79251416c75066791', 'de...     shanecarruth
# 3760  [{'credit_id': '52fe44eec3a36847f80b280b', 'de...  robertrodriguez
# 3761  [{'credit_id': '52fe487dc3a368484e0fb013', 'de...      edwardburns
#
#                                                    soup
# 3757  michaelparle emmaelizaregan patricko'donnell k...
# 3758  kojiyakusho masatohagiwara tsuyoshiujiki annan...
# 3759  shanecarruth davidsullivan caseygooden anandup...
# 3760  carlosgallardo jaimedehoyos petermarquardt rei...
# 3761  edwardburns kerrybishé marshadietlein caitlinf...

# %%
tmdb_5000_movies['overview'].head()
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
titles = tmdb_5000_movies['original_title']
titles = pd.DataFrame(titles)
titles.head(50)
# Out:
#                                  original_title
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# 18                               Men in Black 3
# 19    The Hobbit: The Battle of the Five Armies
# 20                       The Amazing Spider-Man
# 21                                   Robin Hood
# 22          The Hobbit: The Desolation of Smaug
# 23                           The Golden Compass
# 24                                    King Kong
# 25                                      Titanic
# 26                   Captain America: Civil War
# 27                                   Battleship
# 28                               Jurassic World
# 29                                      Skyfall
# 30                                 Spider-Man 2
# 31                                   Iron Man 3
# 32                          Alice in Wonderland
# 33                        X-Men: The Last Stand
# 34                          Monsters University
# 35          Transformers: Revenge of the Fallen
# 36              Transformers: Age of Extinction
# 37                   Oz: The Great and Powerful
# 38                     The Amazing Spider-Man 2
# 39                                 TRON: Legacy
# 40                                       Cars 2
# 41                                Green Lantern
# 42                                  Toy Story 3
# 43                         Terminator Salvation
# 44                                    Furious 7
# 45                                  World War Z
# 46                   X-Men: Days of Future Past
# 47                      Star Trek Into Darkness
# 48                        Jack the Giant Slayer
# 49                             The Great Gatsby

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
def get_list(x):
    if isinstance(x, list):
        if len(x) > 5:
            x = x[:5]
        return x

    return []

# %%
tmdb_5000_movies['director'] = tmdb_5000_movies['crew'].apply(get_director)

features = ['cast', 'genres']
for feature in features:
    tmdb_5000_movies[feature] = tmdb_5000_movies[feature].apply(get_list)

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['cast', 'director', 'genres']

for feature in features:
    tmdb_5000_movies[feature] = tmdb_5000_movies[feature].apply(clean_data)

# %%
def create_soup(x):
    return ' '.join(x['cast']) + ' ' + x['director'] + ' '.join(x['genres'])
tmdb_5000_movies['soup'] = tmdb_5000_movies.apply(create_soup, axis=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(tmdb_5000_movies['soup'])
tfidf_matrix_dense = tfidf_matrix.toarray()
scaler = StandardScaler()
tfidf_matrix_standardized = scaler.fit_transform(tfidf_matrix_dense)

print(tfidf_matrix_standardized.shape)
# Out:
# (3762, 10242)

# %%
knn = NearestNeighbors(n_neighbors=15, metric='cosine', algorithm='brute')
knn.fit(tfidf_matrix_standardized)

def get_recommendation(title, k=10):
    idx = tmdb_5000_movies[tmdb_5000_movies['original_title'] == title].index[0]
    distances, indices = knn.kneighbors(tfidf_matrix_standardized[idx].reshape(1, -1), n_neighbors=k+1)
    print(sorted(distances[0]))
    recommendations = []
    for i in range(1, len(indices[0])):
        recommendations.append(tmdb_5000_movies.iloc[indices[0][i]][['original_title', 'genres', 'popularity', 'cast', 'vote_average', 'director', 'overview']])
    
    return recommendations

# %%
peli = "Jason Bourne"
recommendations = get_recommendation(peli, k=10)
print(f"Recommendations if you saw '{peli}':")
actores = tmdb_5000_movies.query("original_title == @peli")['cast']
for i, recommendation in enumerate(recommendations):
    recommendations[i]['same_actors'] = len(set(actores.values[0]) & set(recommendation['cast']))
pd.DataFrame(recommendations)
# Out:
# [np.float64(0.0), np.float64(0.2931492520451858), np.float64(0.7274923913951588), np.float64(0.7833629794875951), np.float64(0.803241984371125), np.float64(0.8043289892865506), np.float64(0.8398903077785611), np.float64(0.8423712393571026), np.float64(0.8629239737289832), np.float64(0.878030754986121), np.float64(0.8935013773352429)]
# Recommendations if you saw 'Shrek':
#                                          original_title  \
# 554                                             Shrek 2
# 86                                  Shrek Forever After
# 63    The Chronicles of Narnia: The Lion, the Witch ...
# 106                                     Shrek the Third
# 15             The Chronicles of Narnia: Prince Caspian
# 218                                        Jason Bourne
# 2467                                         Black Swan
# 960                                         Joan of Arc
# 2079                                 A Dangerous Method
# 333                      Rise of the Planet of the Apes
#
#                                                genres  popularity  \
# 554   [adventure, animation, comedy, family, fantasy]   47.320801
# 86    [comedy, adventure, fantasy, animation, family]   44.041186
# 63                       [adventure, family, fantasy]   67.391328
# 106   [fantasy, adventure, animation, comedy, family]   42.986467
# 15                       [adventure, family, fantasy]   53.978602
# 218                                [action, thriller]   62.641286
# 2467                                [drama, thriller]   91.285683
# 960          [adventure, drama, action, history, war]   21.084542
# 2079                                [drama, thriller]   27.133277
# 333         [thriller, action, drama, sciencefiction]  138.433168
#
#                                                    cast  vote_average  \
# 554   [mikemyers, eddiemurphy, camerondiaz, julieand...           6.7
# 86    [mikemyers, eddiemurphy, camerondiaz, antoniob...           6.0
# 63    [williammoseley, annapopplewell, skandarkeynes...           6.7
# 106   [mikemyers, eddiemurphy, camerondiaz, julieand...           6.0
# 15    [benbarnes, williammoseley, annapopplewell, sk...           6.3
# 218   [mattdamon, aliciavikander, tommyleejones, vin...           5.9
# 2467  [natalieportman, milakunis, vincentcassel, bar...           7.3
# 960   [millajovovich, dustinhoffman, fayedunaway, jo...           6.2
# 2079  [keiraknightley, viggomortensen, michaelfassbe...           6.2
# 333   [jamesfranco, freidapinto, johnlithgow, brianc...           7.0
#
#              director                                           overview  \
# 554     andrewadamson  Shrek, Fiona and Donkey set off to Far, Far Aw...
# 86       mikemitchell  A bored and domesticated Shrek pacts with deal...
# 63      andrewadamson  Siblings Lucy, Edmund, Susan and Peter step th...
# 106       chrismiller  The King of Far Far Away has died and Shrek an...
# 15      andrewadamson  One year after their incredible adventures in ...
# 218    paulgreengrass  The most dangerous former operative of the CIA...
# 2467  darrenaronofsky  A ballet dancer wins the lead in "Swan Lake" a...
# 960         lucbesson  In 1429 a teenage girl from a remote French vi...
# 2079  davidcronenberg  Seduced by the challenge of an impossible case...
# 333       rupertwyatt  Scientist Will Rodman is determined to find a ...
#
#       same_actors
# 554             3
# 86              3
# 63              0
# 106             3
# 15              0
# 218             1
# 2467            1
# 960             1
# 2079            1
# 333             1

# %%
k = tmdb_5000_movies.query("original_title == @peli")
k
# Out:
#        budget                                  genres     id  \
# 322  95000000  [adventure, animation, comedy, family]  10501
#
#     original_language         original_title  \
# 322                en  The Road to El Dorado
#
#                                               overview  popularity  \
# 322  After a failed swindle, two con-men end up wit...   37.054554
#
#            production_countries release_date spoken_languages  vote_average  \
# 322  [United States of America]   2000-03-31        [English]           7.0
#
#      vote_count  movie_id                  title  \
# 322         858     10501  The Road to El Dorado
#
#                                                   cast  \
# 322  [kennethbranagh, kevinkline, rosieperez, arman...
#
#                                                   crew        director  \
# 322  [{'credit_id': '52fe437c9251416c750122e9', 'de...  donmichaelpaul
#
#                                                   soup
# 322  kennethbranagh kevinkline rosieperez armandass...
