# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ### Load & Preprocess data

# %%
tmdb_5000_credits = pd.read_csv("datasets/movies-2/tmdb_5000_credits.csv")
tmdb_5000_movies = pd.read_csv("datasets/movies-2/tmdb_5000_movies.csv")

# %%
columns_movies = ["budget", "genres", "id", "original_language", "original_title", "overview", "popularity", "production_countries", "release_date", "spoken_languages", "vote_average", "vote_count"]
columns_credits = ["movie_id", "title", "cast", "crew"]

tmdb_5000_movies = tmdb_5000_movies[columns_movies]
tmdb_5000_credits = tmdb_5000_credits[columns_credits]

for column in ["genres", "production_countries", "spoken_languages"]:
    tmdb_5000_movies[column] = tmdb_5000_movies[column].apply(literal_eval)

for column in ["crew", "cast"]:
    tmdb_5000_credits[column] = tmdb_5000_credits[column].apply(literal_eval)

# %%
tmdb_5000_credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 3  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 4  [{'cast_id': 5, 'character': 'John Carter', 'c...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...

# %%
tmdb_5000_movies.head(5)
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   19995
# 1  300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...     285
# 2  245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  206647
# 3  250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   49026
# 4  260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-10
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2007-05-19
# 2  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2015-10-26
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-07-16
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-03-07
#
#                                     spoken_languages  vote_average  vote_count
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...           7.2       11800
# 1           [{'iso_639_1': 'en', 'name': 'English'}]           6.9        4500
# 2  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...           6.3        4466
# 3           [{'iso_639_1': 'en', 'name': 'English'}]           7.6        9106
# 4           [{'iso_639_1': 'en', 'name': 'English'}]           6.1        2124

# %%
def preprocess_dict(column: str, key: str = "name"):
    genres_column = tmdb_5000_movies[column]
    genres_column_processed = []
    for item in genres_column:
        genres_column_processed.append([dic[key] for dic in item])
    return genres_column_processed

# %%
tmdb_5000_movies["genres"] = preprocess_dict("genres")
tmdb_5000_movies["production_countries"] = preprocess_dict("production_countries")
tmdb_5000_movies["spoken_languages"] = preprocess_dict("spoken_languages")

# %%
tmdb_5000_movies.head(5)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                          production_countries release_date  \
# 0  [United States of America, United Kingdom]   2009-12-10
# 1                  [United States of America]   2007-05-19
# 2  [United Kingdom, United States of America]   2015-10-26
# 3                  [United States of America]   2012-07-16
# 4                  [United States of America]   2012-03-07
#
#                                   spoken_languages  vote_average  vote_count
# 0                               [English, Español]           7.2       11800
# 1                                        [English]           6.9        4500
# 2  [Français, English, Español, Italiano, Deutsch]           6.3        4466
# 3                                        [English]           7.6        9106
# 4                                        [English]           6.1        2124

# %%
tmdb_5000_movies = tmdb_5000_movies.merge(tmdb_5000_credits, left_on='id', right_on='movie_id')

# %%
print(tmdb_5000_movies.shape)
tmdb_5000_movies = tmdb_5000_movies[tmdb_5000_movies['budget'].apply(lambda x: x > 0)]
tmdb_5000_movies = tmdb_5000_movies[tmdb_5000_movies['genres'].apply(lambda x: len(x) > 0)]
print(tmdb_5000_movies.shape)
# Out:
# (4803, 16)
# (3762, 16)

# %%
tmdb_5000_movies = tmdb_5000_movies.reset_index(drop=True)

# %%
tmdb_5000_movies["cast"] = preprocess_dict("cast", "name")

# %%
tmdb_5000_movies.head()
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
# 3  250000000               [Action, Crime, Drama, Thriller]   49026
# 4  260000000           [Action, Adventure, Science Fiction]   49529
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
# 2                en                                   Spectre
# 3                en                     The Dark Knight Rises
# 4                en                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                          production_countries release_date  \
# 0  [United States of America, United Kingdom]   2009-12-10
# 1                  [United States of America]   2007-05-19
# 2  [United Kingdom, United States of America]   2015-10-26
# 3                  [United States of America]   2012-07-16
# 4                  [United States of America]   2012-03-07
#
#                                   spoken_languages  vote_average  vote_count  \
# 0                               [English, Español]           7.2       11800
# 1                                        [English]           6.9        4500
# 2  [Français, English, Español, Italiano, Deutsch]           6.3        4466
# 3                                        [English]           7.6        9106
# 4                                        [English]           6.1        2124
#
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...
# 1  [{'credit_id': '52fe4232c3a36847f800b579', 'de...
# 2  [{'credit_id': '54805967c3a36829b5002c41', 'de...
# 3  [{'credit_id': '52fe4781c3a36847f81398c3', 'de...
# 4  [{'credit_id': '52fe479ac3a36847f813eaa3', 'de...

# %%
tmdb_5000_movies['overview'].head()
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bond’s past sends him o...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
titles = tmdb_5000_movies['original_title']
# Out:
# 20                 The Amazing Spider-Man
# 21                             Robin Hood
# 22    The Hobbit: The Desolation of Smaug
# 23                     The Golden Compass
# 24                              King Kong
# 25                                Titanic
# 26             Captain America: Civil War
# 27                             Battleship
# 28                         Jurassic World
# 29                                Skyfall
# 30                           Spider-Man 2
# 31                             Iron Man 3
# 32                    Alice in Wonderland
# 33                  X-Men: The Last Stand
# 34                    Monsters University
# 35    Transformers: Revenge of the Fallen
# 36        Transformers: Age of Extinction
# 37             Oz: The Great and Powerful
# 38               The Amazing Spider-Man 2
# 39                           TRON: Legacy
# Name: original_title, dtype: object

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
def get_list(x):
    if isinstance(x, list):
        if len(x) > 5:
            x = x[:5]
        return x

    return []

# %%
tmdb_5000_movies['director'] = tmdb_5000_movies['crew'].apply(get_director)

features = ['cast', 'genres']
for feature in features:
    tmdb_5000_movies[feature] = tmdb_5000_movies[feature].apply(get_list)

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['cast', 'director', 'genres']

for feature in features:
    tmdb_5000_movies[feature] = tmdb_5000_movies[feature].apply(clean_data)

# %%
def create_soup(x):
    return ' '.join(x['cast']) + ' ' + x['director'] + ' '.join(x['genres'])
tmdb_5000_movies['soup'] = tmdb_5000_movies.apply(create_soup, axis=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(tmdb_5000_movies['soup'])
tfidf_matrix_dense = tfidf_matrix.toarray()
scaler = StandardScaler()
tfidf_matrix_standardized = scaler.fit_transform(tfidf_matrix_dense)

print(tfidf_matrix_standardized.shape)
# Out:
# (3762, 10242)

# %%
knn = NearestNeighbors(n_neighbors=15, metric='cosine', algorithm='brute')
knn.fit(tfidf_matrix_standardized)

def get_recommendation(title, k=10):
    idx = tmdb_5000_movies[tmdb_5000_movies['original_title'] == title].index[0]
    distances, indices = knn.kneighbors(tfidf_matrix_standardized[idx].reshape(1, -1), n_neighbors=k+1)
    print(sorted(distances[0]))
    recommendations = []
    for i in range(1, len(indices[0])):
        recommendations.append(tmdb_5000_movies.iloc[indices[0][i]][['original_title', 'genres', 'popularity', 'cast', 'vote_average', 'director', 'overview']])
    
    return recommendations

# %%
peli = "Back to the Future"
recommendations = get_recommendation(peli, k=10)
print(f"Recommendations if you saw '{peli}':")
actores = tmdb_5000_movies.query("original_title == @peli")['cast']
for i, recommendation in enumerate(recommendations):
    recommendations[i]['same_actors'] = len(set(actores.values[0]) & set(recommendation['cast']))
pd.DataFrame(recommendations)
# Out:
# [np.float64(0.0), np.float64(0.09793959918198814), np.float64(0.6181006363380529), np.float64(0.7847530491331365), np.float64(0.8105847452779072), np.float64(0.8137424569100443), np.float64(0.8614063179007245), np.float64(0.8707759631487063), np.float64(0.8763739033340799), np.float64(0.8829060270402789), np.float64(0.9028804339192884)]
# Recommendations if you saw 'Back to the Future':
#                    original_title  \
# 1129  Back to the Future Part III
# 1116   Back to the Future Part II
# 2933               Action Jackson
# 151                       Beowulf
# 3110             April Fool's Day
# 267                 Stuart Little
# 668        The American President
# 32            Alice in Wonderland
# 1545                            9
# 735           My Favorite Martian
#
#                                                  genres  popularity  \
# 1129        [adventure, comedy, family, sciencefiction]   45.769562
# 1116        [adventure, comedy, family, sciencefiction]   43.345252
# 2933          [action, adventure, comedy, crime, drama]    6.872784
# 151                      [adventure, action, animation]   35.601665
# 3110                                  [horror, mystery]    8.190888
# 267                [animation, fantasy, family, comedy]   30.475297
# 668                            [comedy, drama, romance]   11.056763
# 32                         [family, fantasy, adventure]   78.530105
# 1545  [action, adventure, animation, sciencefiction,...   55.806402
# 735             [comedy, drama, family, sciencefiction]    6.806920
#
#                                                    cast  vote_average  \
# 1129  [michaelj.fox, christopherlloyd, marysteenburg...           7.1
# 1116  [michaelj.fox, christopherlloyd, leathompson, ...           7.4
# 2933  [carlweathers, craigt.nelson, vanity, sharonst...           4.9
# 151   [raywinstone, angelinajolie, anthonyhopkins, r...           5.5
# 3110  [deborahforeman, thomasf.wilson, lloydberry, t...           5.8
# 267   [michaelj.fox, geenadavis, hughlaurie, jonatha...           5.8
# 668   [michaeldouglas, annettebening, michaelj.fox, ...           6.5
# 32    [miawasikowska, johnnydepp, annehathaway, hele...           6.4
# 1545  [christopherplummer, martinlandau, johnc.reill...           6.6
# 735   [jeffdaniels, elizabethhurley, darylhannah, ch...           5.1
#
#             director                                           overview  \
# 1129  robertzemeckis  [the, final, installment, of, the, back, to, t...
# 1116  robertzemeckis  [marty, and, doc, are, at, it, again, in, this...
# 2933   craigr.baxley  [vengence, drives, a, tough, detroit, cop, to,...
# 151   robertzemeckis  [6thcentury, scandinavian, warrior, beowulf, e...
# 3110      fredwalton  [a, group, of, eight, college, friends, gather...
# 267       robminkoff  [the, adventures, of, a, heroic, and, debonair...
# 668        robreiner  [widowed, us, president, andrew, shepherd, one...
# 32         timburton  [alice, an, unpretentious, and, individual, 19...
# 1545      shaneacker  [when, 9, first, comes, to, life, he, finds, h...
# 735     donaldpetrie  [news, producer, tim, ohara, gets, himself, fi...
#
#       same_actors
# 1129            4
# 1116            3
# 2933            1
# 151             0
# 3110            1
# 267             1
# 668             1
# 32              1
# 1545            1
# 735             1

# %%
k = tmdb_5000_movies.query("original_title == @peli")
k
# Out:
#        budget                        genres     id original_language  \
# 32  200000000  [family, fantasy, adventure]  12155                en
#
#          original_title                                           overview  \
# 32  Alice in Wonderland  [alice, an, unpretentious, and, individual, 19...
#
#     popularity        production_countries release_date spoken_languages  \
# 32   78.530105  [United States of America]   2010-03-03        [English]
#
#     vote_average  vote_count  movie_id                title  \
# 32           6.4        4645     12155  Alice in Wonderland
#
#                                                  cast  \
# 32  [miawasikowska, johnnydepp, annehathaway, hele...
#
#                                                  crew   director  \
# 32  [{'credit_id': '52fe44c09251416c7503fbc3', 'de...  timburton
#
#                                                  soup
# 32  miawasikowska johnnydepp annehathaway helenabo...
